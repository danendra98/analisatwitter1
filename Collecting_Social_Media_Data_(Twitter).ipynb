# %%
pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy) (2.21.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.7.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.12.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy) (1.3.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (2019.9.11)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)

# %%
# For our first piece of code, we need to import the package 
# that connects to Twitter. Tweepy is a popular and fully featured
# implementation.

import tweepy

# Use the strings from your Twitter app webpage to populate these four 
# variables. Be sure and put the strings BETWEEN the quotation marks
# to make it a valid Python string.

consumer_key = "2ptaoP0xghWHYtxU3WiszH1Rf"
consumer_secret = "osL5HHJFtkbyHj6M9be9USIPlg7ZV9DrQS6TfCBta5soBBFNhv"
access_token = "352200281-UUqMcrSpcojCcqWCVto0lF9W46XNp37N7bFLykUQ"
access_secret = "flv5zNnyE8PHT8dEiaBk8W8YGUnsVOfHFGSt1LheRFroy"

# %%
# Now we use the configured authentication information to connect
# to Twitter's API
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

print("Connected to Twitter!")
# Out:
# Connected to Twitter!

# %%
# Get tweets from our timeline
public_tweets = api.home_timeline()

# print the first five authors and tweet texts
for tweet in public_tweets[:5]:
    print (tweet.author.screen_name, tweet.author.name, "said:", tweet.text)
# Out:
# SpeakersNow speakers Now said: Jangan pernah sakiti mereka yang ada didekatmu dan menyayangimu, hingga mereka meninggalkanmu. Kesendirian tidak menyenangkan.
# realmadrid Real Madrid C.F.⚽ said: 2⃣5⃣0⃣👏 @ToniKroos: "Ojalá tengamos muchos éxitos más." #HalaMadrid https://t.co/DnB79Ftf3B
# SpeakersNow speakers Now said: keraguan adalah awal dari kegagalan, bagai mana kau bisa mencapai sesuatu jika kau sendiri ragu, yakinlah pada dirimu!
# topikhz Topik said: RT @tsnvtlolii: 3 hal yang membuat orang galau :
#
# 1. Otak kosong
# 2. Dompet kosong
# 3. Omong kosong
#
#       Wkwk...
# topikhz Topik said: Berbagai cara mendapatkanmu
# Tapi cuma bisa satu cara
#
# Mundur

# %%
# Our search string
queryString = "coding"

# Perform the search
matchingTweets = api.search(queryString)

print ("Searched for:", queryString)
print ("Number found:", len(matchingTweets))

# For each tweet that matches our query, print the author and text
print ("\nTweets:")
for tweet in matchingTweets:
    print (tweet.author.screen_name, tweet.author.name, "said :", tweet.text)
# Out:
# Searched for: coding
# Number found: 15
#
# Tweets:
# logudotcom Loganathan Natarajan said : RT @tecmint: #Linux #Programming #coding #softwaretesting #softwaredevelopment  #webdesign #webdeveloper #sysadmins #Network #engineer #cod…
# Silvea12 Andrew Silver said : RT @FreyaHolmer: If you want to begin your path in t̴h̴e̴ ̴d̴a̴r̴k̴ ̴a̴r̴t̴s̴ ̴o̴f̴ ̴w̴i̴t̴c̴h̴c̴r̴a̴f̴t̴ shader coding in Unity, I hosted…
# resilient_ent RESILIENT MEDIA ENT(Benny Quetell) 🎼 said : RT @PythonNews365: Why Python is Perfect for Beginners | Coding Dojo #Pythoncode https://t.co/YuEIOoDXlK https://t.co/En4kwEDjfn https://t.…
# resilient_ent RESILIENT MEDIA ENT(Benny Quetell) 🎼 said : RT @GA_London: Have you ever wished you could code? It looks so cool right? Well @_mattstuddert    is here to help! Come to Coding for Begi…
# _karitu Alekii said : RT @EmmaWedekind: You don't need to spend all of your free time coding to be a great developer 💘
# Taieb_Bot JSBot said : RT @iC0dE_: How to Read Website Source Code by @Shivani_2019 | @iC0dE_ Magazine: https://t.co/U3VEvPNG3R
#
# #programming #coding #webdev #web…
# prettyme0518 Chrysti trajano said : @MMDA  possible po ba ma lifted ung coding ng tuesday due to typhoon? thanks
# iC0dE_ iC0dE said : How to Read Website Source Code by @Shivani_2019 | @iC0dE_ Magazine: https://t.co/U3VEvPNG3R
#
# #programming #coding… https://t.co/vqroBHZbOk
# Olisaemeka042 Deggie said : RT @FinPlanKaluAja1: Someone introduced this to me.
#
# Lambda is a US based coding/IT school, you take classes online at no cost, graduate. L…
# Lohbyen_Wuyep BeBek😊 said : RT @FinPlanKaluAja1: Someone introduced this to me.
#
# Lambda is a US based coding/IT school, you take classes online at no cost, graduate. L…
# LUKACACIC wolfofethereum.eth said : @bitfalls @badcryptobitch @virgilgr @VitalikButerin what if that research was bitconeeect,or  tron or eos or some o… https://t.co/nD2GxzLjBB
# SJ_thl 트밀🌻 said : RT @affective_neuro: 학회 참가중인데 티벳여우님 무슨일이야. 왜 predictive coding 설명에 쓰인거야. https://t.co/x6eezGj0yy
# kly321953 ÖZGÜR KALYONCU said : RT @ArcelikGlobal: You code girl! 🙌
# The children of our employees were invited to participate in a GirlCode workshop to take a step into th…
# iC0dE_ iC0dE said : RT @iC0dE_: Do You Listen to Music While Coding? If So, What Types of Music Do You Prefer to Listen To?
#
# #programming #coding #hacking #pro…
# TheBoxOfChicago The Box Of Chicago said : RT @rSoftwareGore: Coding skill 100 https://t.co/91IshQurGe

# %%
# Lets find only media or links about earthquakes
queryString = "coding (filter:media OR filter:links)"

# Perform the search
matchingTweets = api.search(queryString)

print ("Searched for:", queryString)
print ("Number found:", len(matchingTweets))

# For each tweet that matches our query, print the author and text
print ("\nTweets:")
for tweet in matchingTweets:
    print (tweet.author.screen_name, "saids :", tweet.text)
# Out:
# Searched for: coding (filter:media OR filter:links)
# Number found: 15
#
# Tweets:
# xaelbot saids : RT @iC0dE_: [#TUTORIAL]: Designing a Resume with #CSS by @codegirl_ | @iC0dE_ Magazine: https://t.co/clYh78jHFx
#
# #programming #coding #webd…
# Taieb_Bot saids : RT @iC0dE_: [#TUTORIAL]: Designing a Resume with #CSS by @codegirl_ | @iC0dE_ Magazine: https://t.co/clYh78jHFx
#
# #programming #coding #webd…
# femtech_ saids : RT @codewallblog: HTML, CSS and JavaScript Explained For Beginners - https://t.co/D2svdXweUf   #Developer #node #nodejs #coding #js #angula…
# iC0dE_ saids : [#TUTORIAL]: Designing a Resume with #CSS by @codegirl_ | @iC0dE_ Magazine: https://t.co/clYh78jHFx
#
# #programming… https://t.co/dgLCFbGUIQ
# xaelbot saids : RT @codewallblog: HTML, CSS and JavaScript Explained For Beginners - https://t.co/D2svdXweUf   #Developer #node #nodejs #coding #js #angula…
# MiraTechno saids : RT @MiraTechno: Every morning with my double expresso 😅😍
# #coding #tech #womenintech #coffee #WomenWhoCode https://t.co/Bq2a1qXF8G
# resilient_ent saids : RT @codewallblog: HTML, CSS and JavaScript Explained For Beginners - https://t.co/D2svdXweUf   #Developer #node #nodejs #coding #js #angula…
# blizzcole saids : RT @FinPlanKaluAja1: Someone introduced this to me.
#
# Lambda is a US based coding/IT school, you take classes online at no cost, graduate. L…
# resilient_ent saids : RT @CoderDve: Python for Beginners | Master Python in 30 Days, 10 Projects
# ☞ https://t.co/py0VsRP125
# #code #coding #geek #morioh #developme…
# VuejsCentral saids : RT @VuejsCentral: Sorry, check #stackoverflow for this one🥴
# #javascript #developer #coding #100DaysOfCode https://t.co/10FEEGzr55
# Metti_Hoof saids : RT @jcukier: what a fantastic write up. How wonderful to get a glimpse into the process of large-scale, creative coding projects. https://t…
# AaronCuddeback saids : RT @Websystemer: Learning to Code with Others - https://t.co/LGXsSsFxns
#
#  #coding #development #management #programming #softwaredevelopment
# nikrangerseo saids : Thanks @SiteGround for this epic sale! Happily coding a new site cause of these sweet deals. https://t.co/o7Ab3mBGZb
# coding_ichigo saids : RT @Unnny_: 소드실드 적폐플레이 후기 https://t.co/I6ohpx29Sb
# AaronCuddeback saids : RT @iC0dE_: How to Read Website Source Code by @Shivani_2019 | @iC0dE_ Magazine: https://t.co/U3VEvPNG3R
#
# #programming #coding #webdev #web…

# %%
# Lets find only media or links about earthquakes
queryString = "SEHUN (filter:media OR filter:links)"

# How many tweets should we fetch? Upper limit is 1,500
maxToReturn = 100

# Perform the search, and for each tweet that matches our query, 
# print the author and text
print ("\nTweets:")
for status in tweepy.Cursor(api.search, q=queryString).items(maxToReturn):
    print (status.author.screen_name, "saids", status.text)
# Out:
# Tweets:
# mylastnamesae saids RT @babiejongdae: A fan wanted to be cheered up by sehun, she wrote personal stuff on memo &amp; asked if only sehun can read it. Sehun told se…
# Puji20640939 saids RT @milkteu: seems like sehun misses dubai 🥺😢 https://t.co/ehxqFVnIgE
# qtjonginpie saids RT @morningpassages: Love how camera zoomes in Sehun when his ending line came giving our vocalist the highlight he deserves. His soft soot…
# ErinaKuotaBar2 saids RT @babiejongdae: A fan wanted to be cheered up by sehun, she wrote personal stuff on memo &amp; asked if only sehun can read it. Sehun told se…
# newwccn saids RT @cutesehunpics: #SEHUN: i don't think so https://t.co/QneJnTLUth
# RRRedcap saids RT @cutesehunpics: #SEHUN: i don't think so https://t.co/QneJnTLUth
# kjsoya saids Tolong ya oknum bernama oh sehun apa gak cukup bikin hati saya grundal grundul ?!! https://t.co/ur2HEIOaZD
# gantfeng saids RT @cutesehunpics: #SEHUN: i don't think so https://t.co/QneJnTLUth
# nalbulleojwo saids RT @myeonmehmeh: 191201 #EXO FANSIGN
# OP asked Sehun what's his favourite Disney character and he said seriously "No I don't have any."
# #세…
# lllaffalll saids RT @Gatoonmonpark: เนี่ย โบกแท่งไฟผิดฝั่งไม่ได้นะ ชี้รายคนเลยนะ55555555555555555 นุบอกซ้ายก็ต้องซ้าย พี่จามาโบกขวามั่ยด้าย
#
# SEHUN CUTE
# #세훈…
# yongwonhhan saids RT @milkteu: the transition from sehun to x-sehůn 🔥‼️ https://t.co/pBmgVc3HGc
# ohbobohun saids RT @babiejongdae: A fan wanted to be cheered up by sehun, she wrote personal stuff on memo &amp; asked if only sehun can read it. Sehun told se…
# BGxSEHUN saids RT @milkteu: the transition from sehun to x-sehůn 🔥‼️ https://t.co/pBmgVc3HGc
# sehunboiola saids RT @lordohsehun: sehun has gotten so confident on stage like he literally shines and he MAKES you look at him. you can’t take your eyes off…
# checkinx61 saids RT @WeLove____EXO: 🐥:ผมปอกส้มเยอะมากๆจนขยับแขนซ้ายไม่ได้เลย
#
        
        # For writing out to a file
        self.filePtr = None
        
    # Create a log file
    def set_log_file(self, newFile):
        if ( self.filePtr ):
            self.filePtr.close()
            
        self.filePtr = newFile
        
    # Close log file
    def close_log_file(self):
        if ( self.filePtr ):
            self.filePtr.close()
    
    # Pass data up to parent then check if we should stop
    def on_data(self, data):

        print (self.currentTweetCount)
        
        tweepy.StreamListener.on_data(self, data)
            
        if ( self.currentTweetCount >= self.maxTweetCount ):
            return False

    # Increment the number of statuses we've seen
    def on_status(self, status):
        self.currentTweetCount += 1
        
        # Could write this status to a file instead of to the console
        print (status.text)
        
        # If we have specified a file, write to it
        if ( self.filePtr ):
            self.filePtr.write("%s\n" % status._json)
        
    # Error handling below here
    def on_exception(self, exc):
        print (exc)

    def on_limit(self, track):
        """Called when a limitation notice arrives"""
        print ("Limit", track)
        return

    def on_error(self, status_code):
        """Called when a non-200 status code is returned"""
        print ("Error:", status_code)
        return False

    def on_timeout(self):
        """Called when stream connection times out"""
        print ("Timeout")
        return

    def on_disconnect(self, notice):
        """Called when twitter sends a disconnect notice
        """
        print ("Disconnect:", notice)
        return

    def on_warning(self, notice):
        print ("Warning:", notice)
        """Called when a disconnection warning message arrives"""

listener = LocalStreamListener()
localStream = tweepy.Stream(api.auth, listener)

# Stream based on keywords
localStream.filter(track=['sehun', 'exo'])
# Out:
# 0
# RT @exoonearewe: EXO 엑소 'Obsession' (EXO &amp; X-EXO Ver.) @ EXO THE STAGE
#
# 👉🏻V LIVE URL: https://t.co/SKyYaJIc1Z
#
# #EXO #엑소 #EXOonearewe #weare…
# 1
# RT @kianepower: 191201 강남
# 세훈이에게 전달 했습니다.. 무척 신기하고 좋아하던 고앵이 ㅠ
# 주려고 가져온 거에요? 그래서 줘도 돼요?
# 하니까 당연하죠 우와~ 하며 잘 전시해 둔다고 어케 만들었냐고 따흡 ㅠㅠㅠㅠㅠㅠㅠㅠ https:…
# 2
# RT @MotiExo: 😐😐😐😐😐😐😐😐😐😐 ولم کنید میخوام تا آخر عمرم پوکر بمونم یعنی اون در قابلمرو کرده تو انگشتشون 😐😐😐😐
# https://t.co/0YdFIzcGRs
# #SundayOBS…
# 3
# RT @SecretOfGod100: #EXO ตัวอย่างรายการ Knowing Bros
#
# 🗓7 ธ.ค. 19:00 น.ไทย
#
# https://t.co/pQm5mt62Lg
# 4
# RT @bulbolniyeol: EXO:                               EXO-Ls: https://t.co/aJELeOKoq3
# 5
# RT @qtpiebyunbaek: 191201 EXO OBSESSION FANSIGN
#
# Baekhyun said he'll do a solo concert!!! // OP asked if Baekhyun does a solo concert, wher…
# 6
# RT @qtpiebyunbaek: 191201 EXO OBSESSION FANSIGN
#
# Baekhyun said he'll do a solo concert!!! // OP asked if Baekhyun does a solo concert, wher…
# 7
# RT @yeolwo: i don't think so
# #exo #obsession https://t.co/CFV5xunELF
# 8
# RT @weareoneEXO: EXO 엑소 'Obsession' (EXO &amp; X-EXO Ver.) @ EXO THE STAGE
#
# 👉🏻V LIVE URL: https://t.co/BmPpzt8lYn
#
# #EXO #엑소 #weareoneEXO #EXOon…
# 9
# RT @affecsen: #세훈 #SEHUN #EXO
# 'Obsession'
#
# https://t.co/oX9qr72z45 https://t.co/yobQHF8kCH

# %%
listener = LocalStreamListener()
localStream = tweepy.Stream(api.auth, listener)

# List of screen names to track
screenNames = ['hanyakenanganmu', 'realmadrid', 'speakersnow', 'euro2020']

# Twitter stream uses user IDs instead of names
# so we must convert
userIds = []
for sn in screenNames:
    user = api.get_user(sn)
    userIds.append(user.id_str)

# Stream based on users
localStream.filter(follow=userIds)
# Out:
# 0
# RT @EURO2020: Fancy a summer trip? 🤔
#
# 🏟️ 🇮🇪 🏴󠁧󠁢󠁳󠁣󠁴󠁿 🏴󠁧󠁢󠁥󠁮󠁧󠁿 🇩🇪 🇮🇹 🇷🇺
#
# #EURO2020 | @bookingcom
#
# *2/2*
# 1
# RT @realmadrid: 🏹⚽💥 ¡Centro milimétrico de @ToniKroos que cabecea @SergioRamos al fondo de la red!
# #RMLiga | #HalaMadrid https://t.co/xSxnl…
# 2
# RT @EURO2020: Which city will you be visiting to watch your team? 🤔
#
# 🏟️ 🇳🇱 🇦🇿 🇪🇸 🇷🇴 🇭🇺 🇩🇰
#
# #EURO2020 | @bookingcom
#
# *1/2*
# 3
# @EURO2020 Portugal and how about being champion again ? together we are stronger.
# ON THE WAY TO THE VICTORY
# 4
# RT @EURO2020: The #EURO2020 groups have been drawn! 😍
#
# Which matches are you excited for? https://t.co/CU7SvtNAXq
# 5
# RT @realmadrid: 2⃣5⃣0⃣👏 @ToniKroos: "Ojalá tengamos muchos éxitos más." #HalaMadrid https://t.co/DnB79Ftf3B
# 6
# @EURO2020 Group F excites me, go Portugal.
# 7
# RT @realmadrid: 🇩🇪💫 ¡@ToniKroos cumple 2⃣5⃣0⃣ partidos con el @realmadrid!
# 👏 ¡Enhorabuena! 👏
# #RealMadrid | #HalaMadrid https://t.co/lnFRRaa…
# 8
# coding itu asik
# 9
# @EURO2020 Group F https://t.co/E6FX0L2QPi

# %%
listener = LocalStreamListener()
localStream = tweepy.Stream(api.auth, listener)

# Specify coordinates for a bounding box around area of interest
# In this case, we use San Francisco
swCornerLat = 36.8
swCornerLon = -122.75
neCornerLat = 37.8
neCornerLon = -121.75

boxArray = [swCornerLon, swCornerLat, neCornerLon, neCornerLat]

# Say we want to write these tweets to a file
listener.set_log_file(open("tweet_log.json", "w"))

# Stream based on location
localStream.filter(locations=boxArray)

# Close the log file
listener.close_log_file()
# Out:
# 0
# @ProgrssvOutlet 2) "The point of Socialism IS Communism."  -Karl Marx
# 1
# TEST_LAT/LON: 2492fe42-f98f-4a94-ba2f-1262ba0e33a5
# 2
# TEST_GEO_Hierarchy: 6f4fffd8-e9fc-425f-a97e-82fbbc4f3987
# 3
# It’s December 1st and ronaldo is still here 😂
# 4
# TEST_PLACE: 01939e3f-ae37-4295-8f96-17312d9a77af
# 5
# @brfootball Mi #MonarcasMorelia https://t.co/wKjxxWdnzl
# 6
# it’s all about me.
# 7
# Meee every weekend 😂
# 8
# Getting ready to board my plane back to Vegas
# 9
# @Jax_Collie @AshesOnFur Kinda gay
